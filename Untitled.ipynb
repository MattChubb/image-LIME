# %%
import json
import os
from pathlib import Path


from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from keras.models import Sequential
from keras.layers import Dense
from keras.preprocessing import image

import numpy as np

# %%
# Initialise image classifier

resnet_model = ResNet50(weights='imagenet')
print(resnet_model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 112, 112, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 112, 112, 64) 0           bn_conv1[0][0]
# ...

# %%
# Predict using image

img_path = './kitten.jpg'
source_img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(source_img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = resnet_model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02119022', 'red_fox', 0.60625607), ('n02119789', 'kit_fox', 0.28562093), ('n02113023', 'Pembroke', 0.030727737)]

# %%
# Quick and dirty, using lime library
# %load_ext autoreload
# %autoreload 2
import os,sys
try:
    import lime
except:
    sys.path.append(os.path.join('./lime', 'lime')) # add the current directory
    import lime
# from lime import lime_image

explainer = lime.lime_image.LimeImageExplainer()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-96e74bfc0444> in <module>
#      10 # from lime import lime_image
#      11
# ---> 12 explainer = lime.lime_image.LimeImageExplainer()
#
# AttributeError: module 'lime' has no attribute 'lime_image'

# %%
# Generate training data
## Create noisy versions of the source image
def noisy(image):
    row,col,ch = image.shape
    gauss = np.random.randn(row,col,ch)
    gauss = gauss.reshape(row,col,ch)        
    noisy = image + image * gauss
    return noisy

noisy_images = []
for i in range(1000):
    noisy = noisy(source_img)
    noisy_images.append(noisy)
## Predict noisy versions using resnet
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-51f02acb77c0> in <module>
#      10 noisy_images = []
#      11 for i in range(1000):
# ---> 12     noisy = noisy(source_img)
#      13     noisy_images.append(noisy)
#      14 ## Predict noisy versions using resnet
#
# <ipython-input-24-51f02acb77c0> in noisy(image)
#       2 ## Create noisy versions of the source image
#       3 def noisy(image):
# ----> 4     row,col,ch = image.shape
#       5     gauss = np.random.randn(row,col,ch)
#       6     gauss = gauss.reshape(row,col,ch)
#
# AttributeError: 'Image' object has no attribute 'shape'

# %%
# Initialise LIME model
lime_model = Sequential()
lime_model.add(Dense(32, input_shape=(224, 224)))
lime_model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train LIME model

# %%
# Extract weights from LIME model

# %%
# Display weights as heatmap
